# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from interpret.glassbox import ExplainableBoostingClassifier
from interpret import show

# %%
df = pd.read_csv('archive/loan_data.csv')
df = df.iloc[:1000]
df
# Out:
#      person_age person_gender person_education  person_income  person_emp_exp  \
# 0          22.0        female           Master        71948.0               0
# 1          21.0        female      High School        12282.0               0
# 2          25.0        female      High School        12438.0               3
# 3          23.0        female         Bachelor        79753.0               0
# 4          24.0          male           Master        66135.0               1
# ..          ...           ...              ...            ...             ...
# 995        22.0        female         Bachelor        57005.0               0
# 996        24.0        female      High School        58556.0               0
# 997        23.0          male      High School        30483.0               0
# 998        25.0        female        Associate        67108.0               3
# 999        25.0        female      High School        67409.0               4
#
#     person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0                    RENT    35000.0           PERSONAL          16.02
# 1                     OWN     1000.0          EDUCATION          11.14
# 2                MORTGAGE     5500.0            MEDICAL          12.87
# 3                    RENT    35000.0            MEDICAL          15.23
# 4                    RENT    35000.0            MEDICAL          14.27
# ..                    ...        ...                ...            ...
# 995                  RENT    18000.0  DEBTCONSOLIDATION          10.71
# 996                  RENT    18000.0           PERSONAL           6.54
# 997                   OWN     8000.0           PERSONAL           5.79
# 998                  RENT    18000.0          EDUCATION          12.84
# 999                  RENT    18000.0    HOMEIMPROVEMENT          10.99
#
#      loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                   0.49                         3.0           561
# 1                   0.08                         2.0           504
# 2                   0.44                         3.0           635
# 3                   0.44                         2.0           675
# 4                   0.53                         4.0           586
# ..                   ...                         ...           ...
# 995                 0.32                         3.0           554
# 996                 0.31                         2.0           634
# 997                 0.26                         3.0           574
# 998                 0.27                         2.0           594
# 999                 0.27                         4.0           646
#
#     previous_loan_defaults_on_file  loan_status
# 0                               No            1
# 1                              Yes            0
# 2                               No            1
# 3                               No            1
# 4                               No            1
# ..                             ...          ...
# 995                             No            1
# 996                             No            1
# 997                            Yes            0
# 998                             No            1
# 999                             No            1
#
# [1000 rows x 14 columns]

# %%
X = df.drop('loan_status', axis=1)
y = df['loan_status']

# %% [markdown]
# ### Fast Preprocess

# %%
X.isna().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# dtype: int64

# %%
X['person_gender'].value_counts()
# Out:
# person_gender
# male      553
# female    447
# Name: count, dtype: int64

# %%
X['person_gender'] = X['person_gender'].map({'male': 0, 'female': 1})

# %%
X['person_education'].value_counts()
# Out:
# person_education
# Bachelor       328
# High School    283
# Associate      250
# Master         138
# Doctorate        1
# Name: count, dtype: int64

# %%
X['person_education'] = X['person_education'].map({'High School': 1, 'Associate': 2, 'Bachelor': 3, 'Master': 4, 'Doctorate': 5})

# %%
X['previous_loan_defaults_on_file'].value_counts()
# Out:
# previous_loan_defaults_on_file
# No     703
# Yes    297
# Name: count, dtype: int64

# %%
X['previous_loan_defaults_on_file'] = X['previous_loan_defaults_on_file'].map({'Yes': 1, 'No': 0})

# %%
# As this two would require one-hot encoding, we will drop them
X = X.drop(columns=['person_home_ownership', 'loan_intent'])

# %% [markdown]
# Now that every variable is numerical, let's normalize

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X
# Out:
#      person_age  person_gender  person_education  person_income  \
# 0          22.0              1                 4        71948.0
# 1          21.0              1                 1        12282.0
# 2          25.0              1                 1        12438.0
# 3          23.0              1                 3        79753.0
# 4          24.0              0                 4        66135.0
# ..          ...            ...               ...            ...
# 995        22.0              1                 3        57005.0
# 996        24.0              1                 1        58556.0
# 997        23.0              0                 1        30483.0
# 998        25.0              1                 2        67108.0
# 999        25.0              1                 1        67409.0
#
#      person_emp_exp  loan_amnt  loan_int_rate  loan_percent_income  \
# 0                 0    35000.0          16.02                 0.49
# 1                 0     1000.0          11.14                 0.08
# 2                 3     5500.0          12.87                 0.44
# 3                 0    35000.0          15.23                 0.44
# 4                 1    35000.0          14.27                 0.53
# ..              ...        ...            ...                  ...
# 995               0    18000.0          10.71                 0.32
# 996               0    18000.0           6.54                 0.31
# 997               0     8000.0           5.79                 0.26
# 998               3    18000.0          12.84                 0.27
# 999               4    18000.0          10.99                 0.27
#
#      cb_person_cred_hist_length  credit_score  previous_loan_defaults_on_file
# 0                           3.0           561                               0
# 1                           2.0           504                               1
# 2                           3.0           635                               0
# 3                           2.0           675                               0
# 4                           4.0           586                               0
# ..                          ...           ...                             ...
# 995                         3.0           554                               0
# 996                         2.0           634                               0
# 997                         3.0           574                               1
# 998                         2.0           594                               0
# 999                         4.0           646                               0
#
# [1000 rows x 11 columns]

# %%
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

X
# Out:
#      person_age  person_gender  person_education  person_income  \
# 0       0.00813            1.0              0.75       0.101368
# 1       0.00000            1.0              0.00       0.000000
# 2       0.03252            1.0              0.00       0.000265
# 3       0.01626            1.0              0.50       0.114628
# 4       0.02439            0.0              0.75       0.091492
# ..          ...            ...               ...            ...
# 995     0.00813            1.0              0.50       0.075981
# 996     0.02439            1.0              0.00       0.078616
# 997     0.01626            0.0              0.00       0.030922
# 998     0.03252            1.0              0.25       0.093145
# 999     0.03252            1.0              0.00       0.093656
#
#      person_emp_exp  loan_amnt  loan_int_rate  loan_percent_income  \
# 0             0.000   1.000000       0.727023             0.742424
# 1             0.000   0.014493       0.392318             0.121212
# 2             0.024   0.144928       0.510974             0.666667
# 3             0.000   1.000000       0.672840             0.666667
# 4             0.008   1.000000       0.606996             0.803030
# ..              ...        ...            ...                  ...
# 995           0.000   0.507246       0.362826             0.484848
# 996           0.000   0.507246       0.076818             0.469697
# 997           0.000   0.217391       0.025377             0.393939
# 998           0.024   0.507246       0.508916             0.409091
# 999           0.032   0.507246       0.382030             0.409091
#
#      cb_person_cred_hist_length  credit_score  previous_loan_defaults_on_file
# 0                           0.5      0.316667                             0.0
# 1                           0.0      0.158333                             1.0
# 2                           0.5      0.522222                             0.0
# 3                           0.0      0.633333                             0.0
# 4                           1.0      0.386111                             0.0
# ..                          ...           ...                             ...
# 995                         0.5      0.297222                             0.0
# 996                         0.0      0.519444                             0.0
# 997                         0.5      0.352778                             1.0
# 998                         0.0      0.408333                             0.0
# 999                         1.0      0.552778                             0.0
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### Prediction

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
ebm = ExplainableBoostingClassifier()
ebm.fit(X_train, y_train)
# Out:
# ExplainableBoostingClassifier()

# %%
ebm_global = ebm.explain_global()
show(ebm_global)
# Out:
# Utilizando librería modificada de interpret
# <!-- http://127.0.0.1:7001/2534370906656/ -->
# <iframe src="http://127.0.0.1:7001/2534370906656/" width=100% height=800 frameBorder="0"></iframe>

# %%
ebm_local = ebm.explain_local(X_test, y_test)
show(ebm_local)
# Out:
# [[ 0.05343145 -0.08366151  0.18004936 ...  0.28030289  0.03071651
#   -0.11217586]
#  [ 0.01960964  0.06514355 -0.04096746 ... -0.09533213  0.19608808
#    0.08984029]
#  [-0.02197137  0.06514355 -0.04096746 ...  0.11273568 -0.29195383
#    0.43972341]
#  ...
#  [-0.01142354  0.06514355  0.05567625 ...  0.77939726  0.35285552
#   -0.08310043]
#  [-0.02197137 -0.08366151 -0.04096746 ...  0.73927019  0.37025668
#   -0.14616986]
#  [ 0.01960964  0.06514355  0.18004936 ...  0.36817215 -0.1715051
#    0.36244684]]
# <!-- http://127.0.0.1:7001/2534386132208/ -->
# <iframe src="http://127.0.0.1:7001/2534386132208/" width=100% height=800 frameBorder="0"></iframe>
