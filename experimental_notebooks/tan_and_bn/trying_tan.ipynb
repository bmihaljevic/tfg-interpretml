# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.skbn as skbn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = pd.read_csv("data/X_train.csv")
X_test = pd.read_csv("data/X_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")

# %%
TAN = skbn.BNClassifier(learningMethod="TAN", prior= 'Smoothing', priorWeight = 0.5,
                          discretizationStrategy = 'quantile', usePR = True, significant_digit = 13)

# %%
TAN.fit(X_train, y_train)
# Out:
# c:\Users\javip\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\javip\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_discretization.py:322: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# c:\Users\javip\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_discretization.py:322: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(

# %%
y_test.squeeze()
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 149    1
# 150    0
# 151    1
# 152    0
# 153    0
# Name: diabetes, Length: 154, dtype: int64

# %%
(TAN.predict(X_test) == y_test.squeeze()).sum() / len(y_test)
# Out:
# 0.7857142857142857

# %%
gnb.sideBySide(TAN.bn,gnb.getInference(TAN.bn,size='15!'))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="337pt" height="360pt" viewBox="0.00 0.00 336.83 360.00">
# <g id="graph0" class="graph" transform="scale(0.891089 0.891089) rotate(0) translate(4 400)">
# <title>G</title>
# <!-- dpf -->
# <g id="node1" class="node">
# <title>dpf</title>
# <g id="a_node1"><a xlink:title="(7) dpf">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-156.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">dpf</text>
# </a>
# </g>
# </g>
# <!-- glucose -->
# <g id="node2" class="node">
# <title>glucose</title>
# <g id="a_node2"><a xlink:title="(2) glucose">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="143" cy="-306" rx="39.07" ry="18"/>
# <text text-anchor="middle" x="143" y="-300.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">glucose</text>
# </a>
# </g>
# </g>
# <!-- pregnancies -->
# <g id="node7" class="node">
# <title>pregnancies</title>
# <g id="a_node7"><a xlink:title="(1) pregnancies">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="162" cy="-234" rx="54.93" ry="18"/>
# <text text-anchor="middle" x="162" y="-228.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">pregnancies</text>
# </a>
# </g>
# </g>
# <!-- glucose&#45;&gt;pregnancies -->
# <g id="edge4" class="edge">
# <title>glucose-&gt;pregnancies</title>
# <g id="a_edge4"><a xlink:title="2 → 1">
# <path fill="none" stroke="#4a4a4a" d="M147.7,-287.7C149.72,-280.24 152.14,-271.32 154.41,-262.97"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="157.72,-264.13 156.96,-253.57 150.96,-262.3 157.72,-264.13"/>
# </a>
# </g>
# </g>
# <!-- bmi -->
# <g id="node3" class="node">
# <title>bmi</title>
# <g id="a_node3"><a xlink:title="(6) bmi">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-156.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">bmi</text>
# </a>
# </g>
# </g>
# <!-- triceps -->
# <g id="node5" class="node">
# <title>triceps</title>
# <g id="a_node5"><a xlink:title="(4) triceps">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="303" cy="-90" rx="35.49" ry="18"/>
# <text text-anchor="middle" x="303" y="-84.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">triceps</text>
# </a>
# </g>
# </g>
# <!-- bmi&#45;&gt;triceps -->
# <g id="edge7" class="edge">
# <title>bmi-&gt;triceps</title>
# <g id="a_edge7"><a xlink:title="6 → 4">
# <path fill="none" stroke="#4a4a4a" d="M120.11,-150.45C124.95,-148.19 130.11,-145.92 135,-144 177.21,-127.46 226.87,-112.31 261.2,-102.48"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="262.1,-105.86 270.76,-99.76 260.19,-99.12 262.1,-105.86"/>
# </a>
# </g>
# </g>
# <!-- diastolic -->
# <g id="node4" class="node">
# <title>diastolic</title>
# <g id="a_node4"><a xlink:title="(3) diastolic">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="186" cy="-162" rx="42.14" ry="18"/>
# <text text-anchor="middle" x="186" y="-156.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">diastolic</text>
# </a>
# </g>
# </g>
# <!-- insulin -->
# <g id="node6" class="node">
# <title>insulin</title>
# <g id="a_node6"><a xlink:title="(5) insulin">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="334" cy="-18" rx="36" ry="18"/>
# <text text-anchor="middle" x="334" y="-12.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">insulin</text>
# </a>
# </g>
# </g>
# <!-- triceps&#45;&gt;insulin -->
# <g id="edge9" class="edge">
# <title>triceps-&gt;insulin</title>
# <g id="a_edge9"><a xlink:title="4 → 5">
# <path fill="none" stroke="#4a4a4a" d="M310.5,-72.05C313.93,-64.32 318.08,-54.96 321.92,-46.27"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="325.1,-47.73 325.95,-37.17 318.7,-44.9 325.1,-47.73"/>
# </a>
# </g>
# </g>
# <!-- pregnancies&#45;&gt;dpf -->
# <g id="edge10" class="edge">
# <title>pregnancies-&gt;dpf</title>
# <g id="a_edge10"><a xlink:title="1 → 7">
# <path fill="none" stroke="#4a4a4a" d="M133.7,-218.33C111.54,-206.84 80.75,-190.87 57.94,-179.05"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.6,-175.96 49.12,-174.47 56.38,-182.18 59.6,-175.96"/>
# </a>
# </g>
# </g>
# <!-- pregnancies&#45;&gt;bmi -->
# <g id="edge13" class="edge">
# <title>pregnancies-&gt;bmi</title>
# <g id="a_edge13"><a xlink:title="1 → 6">
# <path fill="none" stroke="#4a4a4a" d="M147.07,-216.41C139.05,-207.5 129.02,-196.35 120.2,-186.56"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="122.84,-184.25 113.55,-179.16 117.64,-188.94 122.84,-184.25"/>
# </a>
# </g>
# </g>
# <!-- pregnancies&#45;&gt;diastolic -->
# <g id="edge15" class="edge">
# <title>pregnancies-&gt;diastolic</title>
# <g id="a_edge15"><a xlink:title="1 → 3">
# <path fill="none" stroke="#4a4a4a" d="M167.93,-215.7C170.49,-208.24 173.55,-199.32 176.41,-190.97"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="179.71,-192.13 179.64,-181.54 173.09,-189.86 179.71,-192.13"/>
# </a>
# </g>
# </g>
# <!-- age -->
# <g id="node9" class="node">
# <title>age</title>
# <g id="a_node9"><a xlink:title="(8) age">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="273" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="273" y="-156.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">age</text>
# </a>
# </g>
# </g>
# <!-- pregnancies&#45;&gt;age -->
# <g id="edge5" class="edge">
# <title>pregnancies-&gt;age</title>
# <g id="a_edge5"><a xlink:title="1 → 8">
# <path fill="none" stroke="#4a4a4a" d="M186.63,-217.46C203.69,-206.71 226.45,-192.35 244.33,-181.08"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="246.07,-184.12 252.67,-175.82 242.34,-178.2 246.07,-184.12"/>
# </a>
# </g>
# </g>
# <!-- diabetes -->
# <g id="node8" class="node">
# <title>diabetes</title>
# <g id="a_node8"><a xlink:title="(0) diabetes">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="229" cy="-378" rx="41.12" ry="18"/>
# <text text-anchor="middle" x="229" y="-372.95" font-family="Times New Roman,serif" font-size="14.00" fill="white">diabetes</text>
# </a>
# </g>
# </g>
# <!-- diabetes&#45;&gt;dpf -->
# <g id="edge2" class="edge">
# <title>diabetes-&gt;dpf</title>
# <g id="a_edge2"><a xlink:title="0 → 7">
# <path fill="none" stroke="#4a4a4a" d="M189.08,-373.05C154.88,-367.59 106.61,-354.65 77,-324 41.83,-287.6 31.36,-226.9 28.27,-191.35"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="31.79,-191.56 27.59,-181.83 24.81,-192.06 31.79,-191.56"/>
# </a>
# </g>
# </g>
# <!-- diabetes&#45;&gt;glucose -->
# <g id="edge11" class="edge">
# <title>diabetes-&gt;glucose</title>
# <g id="a_edge11"><a xlink:title="0 → 2">
# <path fill="none" stroke="#4a4a4a" d="M210.34,-361.81C198.62,-352.27 183.3,-339.8 170.24,-329.17"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="172.76,-326.71 162.8,-323.11 168.34,-332.14 172.76,-326.71"/>
# </a>
# </g>
# </g>
# <!-- diabetes&#45;&gt;bmi -->
# <g id="edge8" class="edge">
# <title>diabetes-&gt;bmi</title>
# <g id="a_edge8"><a xlink:title="0 → 6">
# <path fill="none" stroke="#4a4a4a" d="M189.01,-373.06C157.63,-367.64 115.89,-354.72 95,-324 67.88,-284.11 79.13,-224.88 89.35,-190.48"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="92.58,-191.87 92.26,-181.28 85.91,-189.75 92.58,-191.87"/>
# </a>
# </g>
# </g>
# <!-- diabetes&#45;&gt;diastolic -->
# <g id="edge6" class="edge">
# <title>diabetes-&gt;diastolic</title>
# <g id="a_edge6"><a xlink:title="0 → 3">
# <path fill="none" stroke="#4a4a4a" d="M232.04,-359.95C236.66,-329.9 243.25,-265.94 226,-216 222.5,-205.87 216.26,-196.1 209.74,-187.77"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="212.48,-185.59 203.36,-180.2 207.13,-190.1 212.48,-185.59"/>
# </a>
# </g>
# </g>
# <!-- diabetes&#45;&gt;triceps -->
# <g id="edge3" class="edge">
# <title>diabetes-&gt;triceps</title>
# <g id="a_edge3"><a xlink:title="0 → 4">
# <path fill="none" stroke="#4a4a4a" d="M243.71,-360.89C252.15,-350.89 262.36,-337.44 269,-324 298.41,-264.44 300.03,-245.81 309,-180 311.75,-159.8 310.09,-136.85 307.82,-119.31"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="311.32,-119.02 306.42,-109.63 30

# %%
gnb.showBN(TAN.MarkovBlanket)

# %%
print(dir(TAN))
# Out:
# ['DirichletCsv', 'MarkovBlanket', 'XYfromCSV', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__sklearn_clone__', '__str__', '__subclasshook__', '__weakref__', '_binary_predict', '_build_request_for_signature', '_check_feature_names', '_check_n_features', '_estimator_type', '_get_default_requests', '_get_metadata_request', '_get_param_names', '_get_tags', '_more_tags', '_nary_predict', '_repr_html_', '_repr_html_inner', '_repr_mimebundle_', '_validate_data', '_validate_params', 'beta', 'bn', 'constraints', 'discretizationNbBins', 'discretizationStrategy', 'discretizationThreshold', 'discretizer', 'fit', 'fromModel', 'fromTrainedModel', 'get_metadata_routing', 'get_params', 'isBinaryClassifier', 'label', 'learner', 'learningMethod', 'possibleSkeleton', 'predict', 'predict_proba', 'preparedData', 'prior', 'priorWeight', 'score', 'scoringType', 'set_fit_request', 'set_params', 'set_predict_request', 'set_score_request', 'showROC_PR', 'significant_digit', 'target', 'targetType', 'threshold', 'usePR', 'variableNameIndexDictionary']

# %%
TAN.beta
# Out:
# 1

# %%
TAN.prior
# Out:
# 'Smoothing'

# %%
TAN.priorWeight
# Out:
# 0.5

# %%
TAN.score(X_test, y_test)
# Out:
# 0.7857142857142857

# %%
TAN.get_params()
# Out:
# {'DirichletCsv': None,
#  'beta': 1,
#  'constraints': None,
#  'discretizationNbBins': 5,
#  'discretizationStrategy': 'quantile',
#  'discretizationThreshold': 25,
#  'learningMethod': 'TAN',
#  'possibleSkeleton': None,
#  'prior': 'Smoothing',
#  'priorWeight': 0.5,
#  'scoringType': 'BIC',
#  'significant_digit': 13,
#  'usePR': True}

# %%
TAN.threshold
# Out:
# 0.4409165334115
